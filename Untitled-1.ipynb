# %% [markdown]
# Import and init

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from DatasetLoader import load_dataset
from YoloModel import get_yolo
from Inference import inference, decode_label

hparams = {
    'input_shape': (448,448,3),
    'num_classes': 7,
    'batch_size': 8,
    'epochs': 300,
    'grid_size': 7,
    'num_bboxes': 1,
    'lambda_coord': 10,
    'lambda_noobj': .5,
    'dataset': 'tiny_kitti2'
}

# %% [markdown]
# Restore model

# %%
checkpoint_path = "training_5/cp.ckpt"

model = get_yolo(hparams)
model.load_weights(checkpoint_path)

# %%
detected_boxes = inference('datasets/kitti/data_tracking_image_2/training/image_02/0010/000000.png', hparams, model, 0, True)
# Out:
# 1/1 [==============================] - 0s 492ms/step
